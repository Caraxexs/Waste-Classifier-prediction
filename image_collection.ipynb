# %%
import cv2
import uuid
import os
import time

labels = ['Plastic', 'Metal', 'Glass', 'Paper', 'Organic']
number_imgs = 15
IMAGES_PATH = os.path.join('images', 'collectedimages')

for label in labels:
    label_path = os.path.join(IMAGES_PATH, label)
    os.makedirs(label_path, exist_ok=True)

for label in labels:
    print(f"\nCollecting images for '{label}'...")
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open webcam.")
        continue
    print("Starting in 3 seconds. Please hold the item in front of the camera.")
    time.sleep(3)

    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture image.")
            break
        imgname = os.path.join(IMAGES_PATH, label, f"{label}.{uuid.uuid1()}.jpg")
        cv2.imwrite(imgname, frame)
        print(f"Saved image {imgnum + 1} for '{label}' as {imgname}")
        cv2.imshow('Collecting...', frame)
        time.sleep(1.5)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    print(f"Finished collecting for '{label}'")

print("\nImage collection complete!")
# Out:
# Collecting images for 'Plastic'...
# 2025-05-10 17:49:24.964 Python[15743:1248344] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Starting in 3 seconds. Please hold the item in front of the camera.
# Saved image 1 for 'Plastic' as images/collectedimages/Plastic/Plastic.0554fc50-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 2 for 'Plastic' as images/collectedimages/Plastic/Plastic.06528e9c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 3 for 'Plastic' as images/collectedimages/Plastic/Plastic.0741f388-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 4 for 'Plastic' as images/collectedimages/Plastic/Plastic.083139e8-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 5 for 'Plastic' as images/collectedimages/Plastic/Plastic.09200c8a-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 6 for 'Plastic' as images/collectedimages/Plastic/Plastic.0a0f3d64-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 7 for 'Plastic' as images/collectedimages/Plastic/Plastic.0afbab86-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 8 for 'Plastic' as images/collectedimages/Plastic/Plastic.0bea696a-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 9 for 'Plastic' as images/collectedimages/Plastic/Plastic.0cd95b24-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 10 for 'Plastic' as images/collectedimages/Plastic/Plastic.0dc883a2-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 11 for 'Plastic' as images/collectedimages/Plastic/Plastic.0eb7b65c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 12 for 'Plastic' as images/collectedimages/Plastic/Plastic.0fab4308-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 13 for 'Plastic' as images/collectedimages/Plastic/Plastic.109ae962-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 14 for 'Plastic' as images/collectedimages/Plastic/Plastic.11896f60-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 15 for 'Plastic' as images/collectedimages/Plastic/Plastic.12792898-2d99-11f0-bc79-cafc59118172.jpg
# Finished collecting for 'Plastic'
#
# Collecting images for 'Metal'...
# Starting in 3 seconds. Please hold the item in front of the camera.
# Saved image 1 for 'Metal' as images/collectedimages/Metal/Metal.15413160-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 2 for 'Metal' as images/collectedimages/Metal/Metal.1634f96c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 3 for 'Metal' as images/collectedimages/Metal/Metal.17244e04-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 4 for 'Metal' as images/collectedimages/Metal/Metal.1812aacc-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 5 for 'Metal' as images/collectedimages/Metal/Metal.19024db6-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 6 for 'Metal' as images/collectedimages/Metal/Metal.19f160ea-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 7 for 'Metal' as images/collectedimages/Metal/Metal.1ae09002-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 8 for 'Metal' as images/collectedimages/Metal/Metal.1bcfafb6-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 9 for 'Metal' as images/collectedimages/Metal/Metal.1cbdf7ac-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 10 for 'Metal' as images/collectedimages/Metal/Metal.1da9a2ba-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 11 for 'Metal' as images/collectedimages/Metal/Metal.1e972d1e-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 12 for 'Metal' as images/collectedimages/Metal/Metal.1f86bfaa-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 13 for 'Metal' as images/collectedimages/Metal/Metal.2075f35e-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 14 for 'Metal' as images/collectedimages/Metal/Metal.2164baca-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 15 for 'Metal' as images/collectedimages/Metal/Metal.22544a22-2d99-11f0-bc79-cafc59118172.jpg
# Finished collecting for 'Metal'
#
# Collecting images for 'Glass'...
# Starting in 3 seconds. Please hold the item in front of the camera.
# Saved image 1 for 'Glass' as images/collectedimages/Glass/Glass.25175f38-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 2 for 'Glass' as images/collectedimages/Glass/Glass.260affa8-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 3 for 'Glass' as images/collectedimages/Glass/Glass.26fa64b2-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 4 for 'Glass' as images/collectedimages/Glass/Glass.27e91bb6-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 5 for 'Glass' as images/collectedimages/Glass/Glass.28d8ae38-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 6 for 'Glass' as images/collectedimages/Glass/Glass.29c7923c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 7 for 'Glass' as images/collectedimages/Glass/Glass.2ab69062-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 8 for 'Glass' as images/collectedimages/Glass/Glass.2ba5b91c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 9 for 'Glass' as images/collectedimages/Glass/Glass.2c9443d4-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 10 for 'Glass' as images/collectedimages/Glass/Glass.2d840af4-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 11 for 'Glass' as images/collectedimages/Glass/Glass.2e72b7ee-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 12 for 'Glass' as images/collectedimages/Glass/Glass.2f623512-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 13 for 'Glass' as images/collectedimages/Glass/Glass.30510dc2-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 14 for 'Glass' as images/collectedimages/Glass/Glass.3140184a-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 15 for 'Glass' as images/collectedimages/Glass/Glass.322ef7c6-2d99-11f0-bc79-cafc59118172.jpg
# Finished collecting for 'Glass'
#
# Collecting images for 'Paper'...
# Starting in 3 seconds. Please hold the item in front of the camera.
# Saved image 1 for 'Paper' as images/collectedimages/Paper/Paper.34f2756e-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 2 for 'Paper' as images/collectedimages/Paper/Paper.35e5f6d0-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 3 for 'Paper' as images/collectedimages/Paper/Paper.36d5b7e2-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 4 for 'Paper' as images/collectedimages/Paper/Paper.37c4c670-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 5 for 'Paper' as images/collectedimages/Paper/Paper.38b38cce-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 6 for 'Paper' as images/collectedimages/Paper/Paper.39a24d46-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 7 for 'Paper' as images/collectedimages/Paper/Paper.3a92e602-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 8 for 'Paper' as images/collectedimages/Paper/Paper.3b80b2f6-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 9 for 'Paper' as images/collectedimages/Paper/Paper.3c700b6c-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 10 for 'Paper' as images/collectedimages/Paper/Paper.3d5eed4a-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 11 for 'Paper' as images/collectedimages/Paper/Paper.3e4e25f4-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 12 for 'Paper' as images/collectedimages/Paper/Paper.3f3d6a06-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 13 for 'Paper' as images/collectedimages/Paper/Paper.402c94dc-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 14 for 'Paper' as images/collectedimages/Paper/Paper.411b4cd0-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 15 for 'Paper' as images/collectedimages/Paper/Paper.420a21ca-2d99-11f0-bc79-cafc59118172.jpg
# Finished collecting for 'Paper'
#
# Collecting images for 'Organic'...
# Starting in 3 seconds. Please hold the item in front of the camera.
# Saved image 1 for 'Organic' as images/collectedimages/Organic/Organic.44cdeab8-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 2 for 'Organic' as images/collectedimages/Organic/Organic.45c17f52-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 3 for 'Organic' as images/collectedimages/Organic/Organic.46b0be96-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 4 for 'Organic' as images/collectedimages/Organic/Organic.479f831e-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 5 for 'Organic' as images/collectedimages/Organic/Organic.488f0538-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 6 for 'Organic' as images/collectedimages/Organic/Organic.497df184-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 7 for 'Organic' as images/collectedimages/Organic/Organic.4a6d0788-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 8 for 'Organic' as images/collectedimages/Organic/Organic.4b5bcfe4-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 9 for 'Organic' as images/collectedimages/Organic/Organic.4c4a4098-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 10 for 'Organic' as images/collectedimages/Organic/Organic.4d3a4ebc-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 11 for 'Organic' as images/collectedimages/Organic/Organic.4e29241a-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 12 for 'Organic' as images/collectedimages/Organic/Organic.4f187416-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 13 for 'Organic' as images/collectedimages/Organic/Organic.50073eac-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 14 for 'Organic' as images/collectedimages/Organic/Organic.50f50e70-2d99-11f0-bc79-cafc59118172.jpg
# Saved image 15 for 'Organic' as images/collectedimages/Organic/Organic.51e3e22a-2d99-11f0-bc79-cafc59118172.jpg
# Finished collecting for 'Organic'
#
# Image collection complete!
